# %%
import pandas as pd
import numpy as np
import sympy as sy

from evaluation import FileAnswer, Quizz
file_answer = FileAnswer('CURSO', 'Tema1', 'local')
quizz = Quizz('1', 'CURSO', 'Tema1', 'local')

# %% [markdown]
# ¿Cuál es la derivada de $f(x) = \frac{x^3}{3}$?

# %% [markdown]
# ### Forma cuadrática
#
# $$ f(\mathbf{x}) = \dfrac{1}{2} \mathbf{x}^T A \mathbf{x} - \mathbf{b}^T \mathbf{x} + c $$
#
# Usando los valores de $A$, $B$ y $C$ calcula la forma de $f(\mathbf{x})$

# %%
t = np.linspace(0,1,10)
w = np.sin(t)
opcion = 'c'
derivada = 'x**2'
matriz_np = np.array([[0.10, -1.],[0.30,-1.]] )
array_np = np.array([-200, 20])
flotante = 0.0
entero = 1
complejo = 1 + 5j
logico = True
lista = [0, 1, 3.4003]
#lista = ['a', 'b', 'c']
#tupla = ('a', 'b', 'c')
tupla = (1.2, 3.1416, np.pi)
##diccionario = {1:'k1', 2:'2.0'}
diccionario = {1:1.3, 2:3.14}
conjunto = {4,1,8,0,4,20}

x = sy.Symbol('x')
y = sy.Symbol('y')
A, B, C = matriz_np, array_np, flotante
forma_cuadratica = 0.5 * A[0,0] * x**2 + 0.5 * A[1,1] * y**2 + 0.5 * (A[0,1]+A[1,0])* x * y - B[0] * x - B[1] * y + C

# %%
respuestas = [t,w,opcion,derivada,matriz_np,array_np,flotante,entero,complejo,logico,lista,tupla,diccionario,conjunto,forma_cuadratica]
for i in respuestas:
    print(i)
# Out:
# [0.         0.11111111 0.22222222 0.33333333 0.44444444 0.55555556
#  0.66666667 0.77777778 0.88888889 1.        ]
# [0.         0.11088263 0.22039774 0.3271947  0.42995636 0.52741539
#  0.6183698  0.70169788 0.77637192 0.84147098]
# c
# x**2
# [[ 0.1 -1. ]
#  [ 0.3 -1. ]]
# [-200   20]
# 0.0
# 1
# (1+5j)
# True
# [0, 1, 3.4]
# (1.2, 3.1416, 3.141592653589793)
# {1: 1.3, 2: 3.14}
# {0, 1, 4, 20, 8}
# 0.05*x**2 - 0.35*x*y + 200*x - 0.5*y**2 - 20*y

# %%
file_answer.write('1a', t, 'Deberías checar ...')
file_answer.write('1b', w)
file_answer.write('2', opcion, 'Las opciones válidas son ...')
file_answer.write('3', derivada, 'Checa las reglas de derivación')
file_answer.write('4', matriz_np, 'Checa las entradas de la matriz A')
file_answer.write('5', array_np, 'Checa las entradas del vector B')
file_answer.write('6', flotante, 'Checa el valor de flotante')
file_answer.write('7', entero, 'Checa el valor de entero')
file_answer.write('8', complejo, 'Checa el valor de complejo')
file_answer.write('9', logico, 'Checa  logico')
file_answer.write('10', lista, 'Checa la lista')
file_answer.write('11', tupla, 'Checa la tupla')
file_answer.write('12', diccionario, 'Checa la diccionario')
file_answer.write('13', conjunto, 'Checa la conjunto')
file_answer.write('14', str(forma_cuadratica),'Revisa tus operaciones algebráicas para calcular f(x)')
file_answer.to_file('1')
# Out:
# El directorio :/home/jovyan/macti_lib/macti/CURSO/utils/.ans/Tema1/ ya existe
# Respuestas y retroalimentación almacenadas.

# %%
ans_df2 = pd.read_parquet('../utils/.ans/Tema1/.__ans_1') # Se lee en un DataFrame
ans_df2
# Out:
#                                                   1a  \
# 0  [0.0, 0.1111111111111111, 0.2222222222222222, ...
#
#                                                   1b  2     3  \
# 0  [0.0, 0.11088262850995298, 0.22039774345612226...  c  x**2
#
#                         4           5    6  7           8     9  \
# 0  [0.1, -1.0, 0.3, -1.0]  [-200, 20]  0.0  1  [1.0, 5.0]  True
#
#                 10                                11                     12  \
# 0  [0.0, 1.0, 3.4]  [1.2, 3.1416, 3.141592653589793]  [1.0, 2.0, 1.3, 3.14]
#
#                  13                                              14
# 0  [0, 1, 4, 20, 8]  0.05*x**2 - 0.35*x*y + 200*x - 0.5*y**2 - 20*y

# %%
fee_df2 = pd.read_parquet('../utils/.ans/Tema1/.__fee_1') # Se lee en un DataFrame
fee_df2
# Out:
#                     1a    1b                             2  \
# 0  Deberías checar ...  None  Las opciones válidas son ...
#
#                                 3                                  4  \
# 0  Checa las reglas de derivación  Checa las entradas de la matriz A
#
#                                  5                           6  \
# 0  Checa las entradas del vector B  Checa el valor de flotante
#
#                           7                           8              9  \
# 0  Checa el valor de entero  Checa el valor de complejo  Checa  logico
#
#                10              11                    12                 13  \
# 0  Checa la lista  Checa la tupla  Checa la diccionario  Checa la conjunto
#
#                                                   14
# 0  Revisa tus operaciones algebráicas para calcul...

# %% [markdown]
# # Evaluación de las respuestas

# %%
quizz.eval_numeric('1a', t)
# Out:
# new
# ----------------------------------------
# Tu resultado es correcto.
# ----------------------------------------

# %%
quizz.eval_numeric('1b', w)
# Out:
# new
# ----------------------------------------
# Tu resultado es correcto.
# ----------------------------------------

# %%
quizz.eval_option('2', 'c')
# Out:
# ----------------------------------------
# Tu respuesta: c, es correcta.
# ----------------------------------------

# %%
x = sy.Symbol('x')
resultado = x*x
display(resultado)
# Out:
# x**2

# %%
quizz.eval_expression('3', resultado)
# Out:
# ----------------------------------------
# Tu respuesta:
# x**2
# es correcta.
# ----------------------------------------

# %%
quizz.eval_numeric('4', matriz_np)
# Out:
# new
# ----------------------------------------
# Tu resultado es correcto.
# ----------------------------------------

# %%
quizz.eval_numeric('5', array_np)
# Out:
# new
# ----------------------------------------
# Tu resultado es correcto.
# ----------------------------------------

# %%
quizz.eval_numeric('6', flotante)
# Out:
# ----------------------------------------
# Tu resultado es correcto.
# ----------------------------------------

# %%
quizz.eval_numeric('7', entero)
# Out:
# ----------------------------------------
# Tu resultado es correcto.
# ----------------------------------------

# %%
quizz.eval_numeric('8', complejo)
# Out:
# ----------------------------------------
# Tu resultado es correcto.
# ----------------------------------------

# %%
quizz.eval_numeric('9', logico)
# Out:
# ----------------------------------------
# Tu resultado es correcto.
# ----------------------------------------

# %%
quizz.eval_numeric('10', lista)
# Out:
# ----------------------------------------
# Ocurrió un error en tus cálculos.
# ----------------------------------------
# Hint: Checa la lista
# ----------------------------------------
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/macti_lib/macti/CURSO/Tema1/evaluation.py:197, in Quizz.eval_numeric(self, enum, ans)
#     196         if not np.allclose(ans, list(correct)):
# --> 197             assert_equal(ans, list(correct))
#     198 elif isinstance(ans, tuple):
#
# File /opt/conda/lib/python3.11/unittest/case.py:873, in TestCase.assertEqual(self, first, second, msg)
#     872 assertion_func = self._getAssertEqualityFunc(first, second)
# --> 873 assertion_func(first, second, msg=msg)
#
# File /opt/conda/lib/python3.11/unittest/case.py:1079, in TestCase.assertListEqual(self, list1, list2, msg)
#    1070 """A list-specific equality assertion.
#    1071
#    1072 Args:
#    (...)
#    1077
#    1078 """
# -> 1079 self.assertSequenceEqual(list1, list2, msg, seq_type=list)
#
# File /opt/conda/lib/python3.11/unittest/case.py:1061, in TestCase.assertSequenceEqual(self, seq1, seq2, msg, seq_type)
#    1060 msg = self._formatMessage(msg, standardMsg)
# -> 1061 self.fail(msg)
#
# File /opt/conda/lib/python3.11/unittest/case.py:703, in TestCase.fail(self, msg)
#     702 """Fail immediately, with the given message."""
# --> 703 raise self.failureException(msg)
#
# AssertionError: Lists differ: [0, 1, 3.4003] != [0.0, 1.0, 3.4]
#
# First differing element 2:
# 3.4003
# 3.4
#
# - [0, 1, 3.4003]
# ?           ---
#
# + [0.0, 1.0, 3.4]
# ?   ++   ++
#
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 quizz.eval_numeric('10', lista)
#
# File ~/macti_lib/macti/CURSO/Tema1/evaluation.py:226, in Quizz.eval_numeric(self, enum, ans)
#     223         print()
#     224     print(Fore.RESET + self.__line_len*'-')
# --> 226     raise AssertionError
#     227 else:
#     228     print(Fore.RESET + self.__line_len*'-')
#
# AssertionError:

# %%
quizz.eval_numeric('11', tupla)
# Out:
# ----------------------------------------
# Tu resultado es correcto.
# ----------------------------------------

# %%
quizz.eval_numeric('12', diccionario)

# %%
quizz.eval_numeric('13', conjunto)

# %%
quizz.eval_expression('14', forma_cuadratica)

# %%
x = [1e-5, 1e-3, 1e-1]
y = np.arccos(np.cos(x))
np.testing.assert_allclose(x, y, rtol=1e-1, atol=1e-1)

# %%
print(x)
print(y)
# Out:
# [1e-05, 0.001, 0.1]
# [1.00000004e-05 1.00000000e-03 1.00000000e-01]

# %%
x = [0.1, 0.3]
y = [1/10, .1 + .1 + .1]
print(x)
print(y)
np.allclose(x, y, rtol = 1e-16, atol=1e-10)
# Out:
# [0.1, 0.3]
# [0.1, 0.30000000000000004]
# True

# %%
l1 = ['a', 'b', 'c']
l2 = ['a', 'bi', 'c']
np.testing.assert_equal(x, y)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[98], line 3
#       1 l1 = ['a', 'b', 'c']
#       2 l2 = ['a', 'bi', 'c']
# ----> 3 np.testing.assert_equal(x, y)
#
#     [... skipping hidden 1 frame]
#
# File /opt/conda/lib/python3.11/site-packages/numpy/testing/_private/utils.py:362, in assert_equal(actual, desired, err_msg, verbose)
#     359 try:
#     360     # Explicitly use __eq__ for comparison, gh-2552
#     361     if not (desired == actual):
# --> 362         raise AssertionError(msg)
#     364 except (DeprecationWarning, FutureWarning) as e:
#     365     # this handles the case when the two types are not even comparable
#     366     if 'elementwise == comparison' in e.args[0]:
#
# AssertionError:
# Items are not equal:
# item=1
#
#  ACTUAL: 0.3
#  DESIRED: 0.30000000000000004
