# %%
import numpy as np
from nose.tools import assert_equal
from colorama import Fore

# %%
x = np.array([1,2.2,3])
y = np.array([1,2,3])

# %%
try:
    assert_equal(list(x.flatten()), list(y.flatten()))
except AssertionError as info:
    print(Fore.RESET + 80*'-')
    print(Fore.RED + 'Cuidado: ocurrió un error en tus cálculos: \n {}'.format(info))
    print(Fore.RESET + 80*'-')
    raise AssertionError
else:
    print(Fore.GREEN + '¡Tu resultado es correcto!')
# Out:
# --------------------------------------------------------------------------------
# Cuidado: ocurrió un error en tus cálculos:
#  Lists differ: [1.0, 2.2, 3.0] != [1, 2, 3]
#
# First differing element 1:
# 2.2
# 2
#
# - [1.0, 2.2, 3.0]
# ?   --  --    --
#
# + [1, 2, 3]
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 try:
# ----> 2     assert_equal(list(x.flatten()), list(y.flatten()))
#       3 except AssertionError as info:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\unittest\case.py:873, in TestCase.assertEqual(self, first, second, msg)
#     872 assertion_func = self._getAssertEqualityFunc(first, second)
# --> 873 assertion_func(first, second, msg=msg)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\unittest\case.py:1079, in TestCase.assertListEqual(self, list1, list2, msg)
#    1070 """A list-specific equality assertion.
#    1071
#    1072 Args:
#    (...)
#    1077
#    1078 """
# -> 1079 self.assertSequenceEqual(list1, list2, msg, seq_type=list)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\unittest\case.py:1061, in TestCase.assertSequenceEqual(self, seq1, seq2, msg, seq_type)
#    1060 msg = self._formatMessage(msg, standardMsg)
# -> 1061 self.fail(msg)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\unittest\case.py:703, in TestCase.fail(self, msg)
#     702 """Fail immediately, with the given message."""
# --> 703 raise self.failureException(msg)
#
# AssertionError: Lists differ: [1.0, 2.2, 3.0] != [1, 2, 3]
#
# First differing element 1:
# 2.2
# 2
#
# - [1.0, 2.2, 3.0]
# ?   --  --    --
#
# + [1, 2, 3]
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 7
#       5     print(Fore.RED + 'Cuidado: ocurrió un error en tus cálculos: \n {}'.format(info))
#       6     print(Fore.RESET + 80*'-')
# ----> 7     raise AssertionError
#       8 else:
#       9     print(Fore.GREEN + '¡Tu resultado es correcto!')
#
# AssertionError:

# %%
correcta = False
if correcta:
    print(Fore.GREEN + '¡Tu respuesta es correcta!')
else:
    print(Fore.RESET + 80*'-')
    print(Fore.RED + 'Cuidado: ocurrió un error en tus cálculos y/o en tu respuesta.')
    print(Fore.RESET + 80*'-') 
    raise ValueError
# Out:
# --------------------------------------------------------------------------------
# Cuidado: ocurrió un error en tus cálculos y/o en tu respuesta.
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 8
#       6 print(Fore.RED + 'Cuidado: ocurrió un error en tus cálculos y/o en tu respuesta.')
#       7 print(Fore.RESET + 80*'-')
# ----> 8 raise ValueError
#
# ValueError:

# %%
import os

# %%
print(os.getcwd())
print(os.getcwdb())
# Out:
# /home/luiggi/GitSites/macti_lib/macti
# b'/home/luiggi/GitSites/macti_lib/macti'
